# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer(
    "all-MiniLM-L6-v2"
)

print("Model ready")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Model ready

# %%
sentences = [
    "Machine learning is amazing",
    "Artificial intelligence is powerful",
    "I cooked pasta yesterday"
]

embeddings = model.encode(sentences)

print(embeddings.shape)
# Out:
# (3, 384)

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(embeddings)

print(similarity_matrix)
# Out:
# [[1.         0.5832358  0.12668452]
#  [0.5832358  0.9999998  0.08991203]
#  [0.12668452 0.08991203 1.0000001 ]]

# %%
import numpy as np

query_index = 0

similarities = similarity_matrix[query_index]

most_similar = np.argsort(similarities)[::-1]

for idx in most_similar:
    print(sentences[idx], similarities[idx])
# Out:
# Machine learning is amazing 1.0
# Artificial intelligence is powerful 0.5832358
# I cooked pasta yesterday 0.12668452
